# %%
import pandas as pd

# %%
ds=pd.read_csv("general_data.csv")

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
ds_y=ds[ds['Attrition']==1]
ds_n=ds[ds['Attrition']==0]

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(24,24))
sns.heatmap(ds.corr(),cmap='rainbow',annot=True)
plt.show()

# %%
sns.distplot(ds['Age'])
plt.show()

# %%
plt.hist(ds['Education'])
plt.show()

# %%
plt.hist(ds['TrainingTimesLastYear'])
plt.show()
